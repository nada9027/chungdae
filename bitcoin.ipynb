# %% [markdown]
# <a href="https://colab.research.google.com/github/nada9027/chungdae/blob/main/bitcoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 140.9 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 웹 페이지 제목 설정
st.title("실시간 비트코인 시세 대시보드")

# 데이터 가져오기 (기존 코드 활용)
@st.cache_data(ttl=600) # 10분마다 데이터를 새로고침하도록 설정
def get_data():
    url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
    params = {'vs_currency': 'usd', 'days': '30', 'interval': 'daily'}
    response = requests.get(url, params=params)
    return response.json()

data = get_data()
df = pd.DataFrame(data['prices'], columns=['timestamp', 'price'])
df['date'] = pd.to_datetime(df['timestamp'], unit='ms')

# 시각화 출력
st.subheader("최근 30일 시세 추이")
st.line_chart(df.set_index('date')['price']) # Streamlit 전용 인터랙티브 차트
# Out:
# 2026-01-20 06:36:03.236 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 06:36:03.680
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-01-20 06:36:03.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 06:36:03.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 06:36:03.684 No runtime found, using MemoryCacheStorageManager
# 2026-01-20 06:36:03.691 No runtime found, using MemoryCacheStorageManager
# 2026-01-20 06:36:03.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 06:36:03.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
